# %%
import pandas as pd
df = pd.read_csv("students_records.csv")
print(df)
# Out:
#    RollNo     Name Gender  Attendance  InternalMarks  ExternalMarks
# 0     101     Ravi      M          85             32              55
# 1     102    Priya      F          92             38              58
# 2     103    Kiran      M          78             28              45
# 3     104      Anu      F          95             40              60
# 4     105     Sita      F          88             35              54
# 5     106      Raj      M          70             25              40
# 6     107    Divya      F          90             37              57
# 7     108     Arun      M          82             30              48
# 8     109  Keerthi      F          96             39              59
# 9     110   Naveen      M          75             27              44

# %%
print("First Five Records: ")
print(df.head())
# Out:
# First Five Records:
#    RollNo   Name Gender  Attendance  InternalMarks  ExternalMarks
# 0     101   Ravi      M          85             32              55
# 1     102  Priya      F          92             38              58
# 2     103  Kiran      M          78             28              45
# 3     104    Anu      F          95             40              60
# 4     105   Sita      F          88             35              54

# %%
print("Last Five Records: ")
print(df.tail())
# Out:
# Last Five Records:
#    RollNo     Name Gender  Attendance  InternalMarks  ExternalMarks
# 5     106      Raj      M          70             25              40
# 6     107    Divya      F          90             37              57
# 7     108     Arun      M          82             30              48
# 8     109  Keerthi      F          96             39              59
# 9     110   Naveen      M          75             27              44

# %%
print("Number of rows and columns:")
print(df.shape)
# Out:
# Number of rows and columns:
# (10, 6)

# %%
print("Column names:")
print(df.columns)
# Out:
# Index(['RollNo', 'Name', 'Gender', 'Attendance', 'InternalMarks',
#        'ExternalMarks '],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# RollNo             int64
# Name              object
# Gender            object
# Attendance         int64
# InternalMarks      int64
# ExternalMarks      int64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RollNo          10 non-null     int64
#  1   Name            10 non-null     object
#  2   Gender          10 non-null     object
#  3   Attendance      10 non-null     int64
#  4   InternalMarks   10 non-null     int64
#  5   ExternalMarks   10 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 612.0+ bytes
# None

# %%
print(df['Attendance'].mean())
# Out:
# 85.1

# %%
print(df['InternalMarks'].mean())
# Out:
# 33.1

# %%
print(df['ExternalMarks '].mean())
# Out:
# 52.0

# %%
print(df['InternalMarks'].max())
# Out:
# 40

# %%
print(df['ExternalMarks '].max())
# Out:
# 60

# %%
print(df['InternalMarks'].min())
print(df['ExternalMarks '].min())
# Out:
# 25
# 40

# %%
print(df['InternalMarks'].std())
# Out:
# 5.425249610233001
#           RollNo  Attendance  InternalMarks  ExternalMarks
# count   10.00000   10.000000       10.00000       10.000000
# mean   105.50000   85.100000       33.10000       52.000000
# std      3.02765    8.736259        5.42525        7.149204
# min    101.00000   70.000000       25.00000       40.000000
# 25%    103.25000   79.000000       28.50000       45.750000
# 50%    105.50000   86.500000       33.50000       54.500000
# 75%    107.75000   91.500000       37.75000       57.750000
# max    110.00000   96.000000       40.00000       60.000000

# %%
print(df.describe())
# Out:
#           RollNo  Attendance  InternalMarks  ExternalMarks
# count   10.00000   10.000000       10.00000       10.000000
# mean   105.50000   85.100000       33.10000       52.000000
# std      3.02765    8.736259        5.42525        7.149204
# min    101.00000   70.000000       25.00000       40.000000
# 25%    103.25000   79.000000       28.50000       45.750000
# 50%    105.50000   86.500000       33.50000       54.500000
# 75%    107.75000   91.500000       37.75000       57.750000
# max    110.00000   96.000000       40.00000       60.000000

# %%
df['Total_marks'] = df['InternalMarks']+df['ExternalMarks ']
print(df)
# Out:
#    RollNo     Name Gender  Attendance  InternalMarks  ExternalMarks   \
# 0     101     Ravi      M          85             32              55
# 1     102    Priya      F          92             38              58
# 2     103    Kiran      M          78             28              45
# 3     104      Anu      F          95             40              60
# 4     105     Sita      F          88             35              54
# 5     106      Raj      M          70             25              40
# 6     107    Divya      F          90             37              57
# 7     108     Arun      M          82             30              48
# 8     109  Keerthi      F          96             39              59
# 9     110   Naveen      M          75             27              44
#
#    Total_marks
# 0           87
# 1           96
# 2           73
# 3          100
# 4           89
# 5           65
# 6           94
# 7           78
# 8           98
# 9           71

# %%
df['Percentage'] = (df['Total_marks']/100)*100
print(df)
# Out:
#    RollNo     Name Gender  Attendance  InternalMarks  ExternalMarks   \
# 0     101     Ravi      M          85             32              55
# 1     102    Priya      F          92             38              58
# 2     103    Kiran      M          78             28              45
# 3     104      Anu      F          95             40              60
# 4     105     Sita      F          88             35              54
# 5     106      Raj      M          70             25              40
# 6     107    Divya      F          90             37              57
# 7     108     Arun      M          82             30              48
# 8     109  Keerthi      F          96             39              59
# 9     110   Naveen      M          75             27              44
#
#    Total_marks  Percentage
# 0           87        87.0
# 1           96        96.0
# 2           73        73.0
# 3          100       100.0
# 4           89        89.0
# 5           65        65.0
# ...

# %%
print(df[df['Attendance']>90])
# Out:
#    RollNo     Name Gender  Attendance  InternalMarks  ExternalMarks   \
# 1     102    Priya      F          92             38              58
# 3     104      Anu      F          95             40              60
# 8     109  Keerthi      F          96             39              59
#
#    Total_marks  Percentage
# 1           96        96.0
# 3          100       100.0
# 8           98        98.0

# %%
print(df[df['Total_marks']>90])
# Out:
#    RollNo     Name Gender  Attendance  InternalMarks  ExternalMarks   \
# 1     102    Priya      F          92             38              58
# 3     104      Anu      F          95             40              60
# 6     107    Divya      F          90             37              57
# 8     109  Keerthi      F          96             39              59
#
#    Total_marks  Percentage
# 1           96        96.0
# 3          100       100.0
# 6           94        94.0
# 8           98        98.0

# %%
print(df[df['Gender']=='F'])
# Out:
#    RollNo     Name Gender  Attendance  InternalMarks  ExternalMarks   \
# 1     102    Priya      F          92             38              58
# 3     104      Anu      F          95             40              60
# 4     105     Sita      F          88             35              54
# 6     107    Divya      F          90             37              57
# 8     109  Keerthi      F          96             39              59
#
#    Total_marks  Percentage
# 1           96        96.0
# 3          100       100.0
# 4           89        89.0
# 6           94        94.0
# 8           98        98.0

# %%
print(df[df['Gender']=='M'])
# Out:
#    RollNo    Name Gender  Attendance  InternalMarks  ExternalMarks   \
# 0     101    Ravi      M          85             32              55
# 2     103   Kiran      M          78             28              45
# 5     106     Raj      M          70             25              40
# 7     108    Arun      M          82             30              48
# 9     110  Naveen      M          75             27              44
#
#    Total_marks  Percentage
# 0           87        87.0
# 2           73        73.0
# 5           65        65.0
# 7           78        78.0
# 9           71        71.0

# %%
print(df[df['ExternalMarks ']<50])
# Out:
#    RollNo    Name Gender  Attendance  InternalMarks  ExternalMarks   \
# 2     103   Kiran      M          78             28              45
# 5     106     Raj      M          70             25              40
# 7     108    Arun      M          82             30              48
# 9     110  Naveen      M          75             27              44
#
#    Total_marks  Percentage
# 2           73        73.0
# 5           65        65.0
# 7           78        78.0
# 9           71        71.0

# %%
#Task - E
highest = df.loc[df["Total_marks"].idxmax()]
print(highest)
# Out:
# RollNo              104
# Name                Anu
# Gender                F
# Attendance           95
# InternalMarks        40
# ExternalMarks        60
# Total_marks         100
# Percentage        100.0
# Name: 3, dtype: object

# %%
lowest = df.loc[df['Total_marks'].idxmin()]
print(lowest)
# Out:
# RollNo             106
# Name               Raj
# Gender               M
# Attendance          70
# InternalMarks       25
# ExternalMarks       40
# Total_marks         65
# Percentage        65.0
# Name: 5, dtype: object

# %%
print(df['Total_marks'].head(3))
# Out:
# 0    87
# 1    96
# 2    73
# Name: Total_marks, dtype: int64

# %%
lowest = df.loc[df['Total_marks'].idxmin()]
print(lowest)
# Out:
# RollNo    106
# Name      Raj
# Gender      M
# Name: 5, dtype: object

# %%
top3 = df.nlargest(3,'Total_marks')
top3
# Out:
#    RollNo     Name Gender  Attendance  InternalMarks  ExternalMarks   \
# 3     104      Anu      F          95             40              60
# 8     109  Keerthi      F          96             39              59
# 1     102    Priya      F          92             38              58
#
#    Total_marks  Percentage
# 3          100       100.0
# 8           98        98.0
# 1           96        96.0

# %%
bot3 = df.nsmallest(3,'Total_marks')
bot3
# Out:
#    RollNo    Name Gender  Attendance  InternalMarks  ExternalMarks   \
# 5     106     Raj      M          70             25              40
# 9     110  Naveen      M          75             27              44
# 2     103   Kiran      M          78             28              45
#
#    Total_marks  Percentage
# 5           65        65.0
# 9           71        71.0
# 2           73        73.0

# %%
class_avg = df['Total_marks'].mean()

students_above_avg = (df['Total_marks'] > class_avg).sum()
print(students_above_avg)
# Out:
# 6

# %%
#Task-F
print("Average Total Marks (Male)")
print(df[df["Gender"]=="M"]["Total_marks"].mean())

print("Average Total Marks (Female)")
print(df[df["Gender"]=="F"]["Total_marks"].mean())

print("Average Attendance by Gender")
print(df.groupby("Gender")["Attendance"].mean())
# Out:
# Average Total Marks (Male)
# 74.8
# Average Total Marks (Female)
# 95.4
# Average Attendance by Gender
# Gender
# F    92.2
# M    78.0
# Name: Attendance, dtype: float64

# %%
# Task G: using MATPLOT_LIB
# Bar Chart
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.bar(df["Name"], df["Total_marks"])
plt.title("Total Marks of Students")
plt.xlabel("Students")
plt.ylabel("Total Marks")
plt.show()

# %%
# Histogram
plt.figure(figsize=(6,5))
plt.hist(df["Attendance"], bins=5)
plt.title("Attendance Distribution")
plt.xlabel("Attendance")
plt.ylabel("Frequency")
plt.show()

# %%
# Pie Chart
gender_count = df["Gender"].value_counts()

plt.figure(figsize=(6,6))
plt.pie(gender_count,
        labels=gender_count.index,
        autopct="%1.1f%%",
        startangle=90)
plt.title("Gender Distribution")
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(6,5))
plt.scatter(df["Attendance"], df["Total_marks"])
plt.title("Attendance vs Total Marks")
plt.xlabel("Attendance")
plt.ylabel("Total Marks")
plt.show()

# %%
print("OBSERVATIONS:")
print("1. Female students have a higher average attendance than male students.")
print("2. Students with higher attendance generally scored higher Total Marks.")
print("3. Anu scored the highest Total Marks, while Raj scored the lowest.")

print("\nConclusion:")
print("Higher attendance appears to be associated with better academic performance.")
# Out:
# OBSERVATIONS:
# 1. Female students have a higher average attendance than male students.
# 2. Students with higher attendance generally scored higher Total Marks.
# 3. Anu scored the highest Total Marks, while Raj scored the lowest.
#
# Conclusion:
# Higher attendance appears to be associated with better academic performance.
